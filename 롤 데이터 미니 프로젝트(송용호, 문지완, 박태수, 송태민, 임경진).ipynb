{'metadata': {'dataVersion': '2', 'matchId': '...
# 18  KR_6865331583  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  KR_6865246398  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  KR_6864792616  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  KR_6877459101  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  KR_6877314852  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  KR_6877210819  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  KR_6742963585  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  KR_6742896721  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  KR_6741692753  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  KR_6715315507  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  KR_6703070781  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  KR_6702973522  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  KR_6854359191  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  KR_6854290578  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  KR_6854249660  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  KR_6849557405  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  KR_6849520062  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  KR_6849457881  {'metadata': {'dataVersion': '2', 'matchId': '...
#
#                                             timelines
# 0   {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  {'metadata': {'dataVersion': '2', 'matchId': '...

# %%
df_EMERALD = get_rawdata('EMERALD')
# Out:
# get summonerId....
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.06s/it]
# get puuId.....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:12<00:00,  1.02s/it]
# get match_id....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:12<00:00,  1.01s/it]
# get matches & timeline....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [01:24<00:00,  2.34s/it]

# %%
df_EMERALD
# Out:
#          match_id                                            matches  \
# 0   KR_6881841705  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   KR_6865771813  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   KR_6826337095  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   KR_6806658814  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   KR_6806606920  {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   KR_6806567736  {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   KR_6659993254  {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   KR_6659929923  {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   KR_6659882904  {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   KR_6879768123  {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  KR_6879694942  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  KR_6879628709  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  KR_6881748416  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  KR_6881731091  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  KR_6881702475  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  KR_6881224219  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  KR_6881107331  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  KR_6881001678  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  KR_6872496359  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  KR_6872417702  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  KR_6872345207  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  KR_6881151971  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  KR_6881069048  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  KR_6880960163  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  KR_6756335105  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  KR_6756296168  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  KR_6756238976  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  KR_6873676806  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  KR_6863342849  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  KR_6863260086  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  KR_6824995488  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  KR_6824965928  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  KR_6824967207  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  KR_6815897976  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  KR_6814213279  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  KR_6814157909  {'metadata': {'dataVersion': '2', 'matchId': '...
#
#                                             timelines
# 0   {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  {'metadata': {'dataVersion': '2', 'matchId': '...

# %%
df_DIAMOND = get_rawdata('DIAMOND')
# Out:
# get summonerId....
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.07s/it]
# get puuId.....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:11<00:00,  1.01it/s]
# get match_id....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:12<00:00,  1.03s/it]
# get matches & timeline....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [01:39<00:00,  2.78s/it]

# %%
df_DIAMOND
# Out:
#          match_id                                            matches  \
# 0   KR_6832252571  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   KR_6829592268  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   KR_6818432121  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   KR_6874529490  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   KR_6874510129  {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   KR_6873859309  {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   KR_6871909372  {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   KR_6870662630  {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   KR_6870541720  {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   KR_6879813144  {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  KR_6879777547  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  KR_6879746317  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  KR_6879109921  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  KR_6878930184  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  KR_6878806427  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  KR_6856569008  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  KR_6856550621  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  KR_6856511401  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  KR_6857667836  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  KR_6857657293  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  KR_6857633441  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  KR_6843104381  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  KR_6830833206  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  KR_6830815385  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  KR_6873652250  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  KR_6873558579  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  KR_6873460619  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  KR_6880004860  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  KR_6879998325  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  KR_6879989101  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  KR_6874164154  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  KR_6874127717  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  KR_6874099680  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  KR_6876991705  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  KR_6872316906  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  KR_6872269113  {'metadata': {'dataVersion': '2', 'matchId': '...
#
#                                             timelines
# 0   {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  {'metadata': {'dataVersion': '2', 'matchId': '...
# 13  {'metadata': {'dataVersion': '2', 'matchId': '...
# 14  {'metadata': {'dataVersion': '2', 'matchId': '...
# 15  {'metadata': {'dataVersion': '2', 'matchId': '...
# 16  {'metadata': {'dataVersion': '2', 'matchId': '...
# 17  {'metadata': {'dataVersion': '2', 'matchId': '...
# 18  {'metadata': {'dataVersion': '2', 'matchId': '...
# 19  {'metadata': {'dataVersion': '2', 'matchId': '...
# 20  {'metadata': {'dataVersion': '2', 'matchId': '...
# 21  {'metadata': {'dataVersion': '2', 'matchId': '...
# 22  {'metadata': {'dataVersion': '2', 'matchId': '...
# 23  {'metadata': {'dataVersion': '2', 'matchId': '...
# 24  {'metadata': {'dataVersion': '2', 'matchId': '...
# 25  {'metadata': {'dataVersion': '2', 'matchId': '...
# 26  {'metadata': {'dataVersion': '2', 'matchId': '...
# 27  {'metadata': {'dataVersion': '2', 'matchId': '...
# 28  {'metadata': {'dataVersion': '2', 'matchId': '...
# 29  {'metadata': {'dataVersion': '2', 'matchId': '...
# 30  {'metadata': {'dataVersion': '2', 'matchId': '...
# 31  {'metadata': {'dataVersion': '2', 'matchId': '...
# 32  {'metadata': {'dataVersion': '2', 'matchId': '...
# 33  {'metadata': {'dataVersion': '2', 'matchId': '...
# 34  {'metadata': {'dataVersion': '2', 'matchId': '...
# 35  {'metadata': {'dataVersion': '2', 'matchId': '...

# %%
query_mysql = """
create table lol_datas_DIAMOND(gameId varchar(30), gameDuration int, allInPings int, assistMePings int, baitPings int,basicPings int,commandPings int,dangerPings int,enemyMissingPings int, getBackPings int,holdPings int, needVisionPings int, onMyWayPings int,pushPings int, visionClearedPings int ,summonerName varchar(50),
summonerLevel int, participantId int, championName varchar(50), champExperience int,
teamPosition varchar(50), teamId int, win varchar(50), kills int, deaths int, assists int,
totalDamageDealtToChampions int ,totalDamageTaken int, g_2 int, g_3 int, g_4 int, g_5 int,g_6 int,g_7 int,
g_8 int,g_9 int,g_10 int,g_11 int,g_12 int,g_13 int,g_14 int,
g_15 int,g_16 int,g_17 int,g_18 int,g_19 int,g_20 int, Sum_Selected int, tier varchar(10)
)
"""

# %%
conn = connect_mysql()

# %%
sql_execute(conn,query_mysql)
# Out:
# ()

# %%
df.iloc[0].matches['info']['participants']

# %%
df.iloc[i].timelines['info']['frames'][2]['participantFrames'][str(9)]['totalGold']
# Out:
# 584

# %%
def lane_processing(tower_lane, tower_team, lane, team):
    if (tower_lane[0] == lane[0]) and (tower_team == team):
        return 1
    else:
        return 0

# %%
def assi_calc(y):
    try:
        return ','.join(list(map(lambda x: str(x), y['assistingParticipantIds'])))
    except:
        return ''

# %%
def insert_matches_timeline_mysql(row,conn):
    # lambda를 이용해서 progress_apply를 통해 insert할 구문 만들기
    query = (
             f'insert into lol_datas_IRON(gameId, gameDuration, gameVersion, summonerName, summonerLevel, participantId,'
             f'championName, champExperience, teamPosition, teamId, win, kills, deaths, assists,'
             f'totalDamageDealtToChampions, totalDamageTaken, g_5, g_6, g_7, g_8, g_9, g_10, g_11, g_12 ,g_13,g_14,'
             f'g_15, g_16, g_17, g_18, g_19, g_20, g_21, g_22, g_23, g_24, g_25)'
             f'values(\'{row.gameId}\',{row.gameDuration}, \'{row.gameVersion}\', \'{row.summonerName}\','
             f'{row.summonerLevel}, {row.participantId},\'{row.championName}\',{row.champExperience},'
             f'\'{row.teamPosition}\', {row.teamId}, \'{row.win}\', {row. kills}, {row.deaths}, {row.assists},'
             f'{row.totalDamageDealtToChampions},{row.totalDamageTaken},{row.g_5},{row.g_6},{row.g_7},{row.g_8},'
             f'{row.g_9},{row.g_10},{row.g_11},{row.g_12},{row.g_13},{row.g_14},{row.g_15},{row.g_16},{row.g_17},'
             f'{row.g_18},{row.g_19},{row.g_20},{row.g_21},{row.g_22},{row.g_23},{row.g_24},{row.g_25})'
             f'ON DUPLICATE KEY UPDATE '
             f'gameId = \'{row.gameId}\', gameDuration = {row.gameDuration}, gameVersion = \'{row.gameVersion}\', summonerName= \'{row.summonerName}\','
             f'summonerLevel = {row.summonerLevel},participantId = {row.participantId},championName = \'{row.championName}\','
             f'champExperience = {row.champExperience}, teamPosition = \'{row.teamPosition}\', teamId = {row.teamId},win = \'{row.win}\','
             f'kills = {row. kills}, deaths = {row.deaths}, assists = {row.assists}, totalDamageDealtToChampions = {row.totalDamageDealtToChampions},'
             f'totalDamageTaken = {row.totalDamageTaken},g_5 = {row.g_5},g_6 = {row.g_6},g_7 = {row.g_7},g_8 = {row.g_8},g_9 = {row.g_9},'
             f'g_10 = {row.g_10},g_11 = {row.g_11},g_12 = {row.g_12},g_13 = {row.g_13},g_14 = {row.g_14},g_15 = {row.g_15},g_16 = {row.g_16},g_17 = {row.g_17},'
             f'g_18 = {row.g_18},g_19 = {row.g_19},g_20 = {row.g_20},g_21 = {row.g_21},g_22 = {row.g_22},g_23 = {row.g_23},g_24 = {row.g_24},g_25 = {row.g_25}'
            )
    mysql_execute(query,conn)
    return query

# %%
conn = connect_mysql()
query = 'select * from lol_datas_IRON'
result = sql_execute_dict(conn,query)
conn.close()

# %%
result_df1 = pd.DataFrame(result)

# %%
result_df1.describe()
# Out:
#        gameDuration   allInPings  assistMePings    baitPings  basicPings  \
# count   7788.000000  7788.000000    7788.000000  7788.000000      7788.0
# mean    1652.003852     0.261171       2.227144     0.016307         0.0
# std      479.204406     1.443192       4.127684     0.189939         0.0
# min      901.000000     0.000000       0.000000     0.000000         0.0
# 25%     1267.000000     0.000000       0.000000     0.000000         0.0
# 50%     1648.000000     0.000000       0.000000     0.000000         0.0
# 75%     1972.000000     0.000000       3.000000     0.000000         0.0
# max     3101.000000    97.000000      50.000000     7.000000         0.0
#
#        commandPings  dangerPings  enemyMissingPings  getBackPings  \
# count   7788.000000       7788.0        7788.000000   7788.000000
# mean       4.455701          0.0           4.455829      2.363508
# std        7.001492          0.0           6.227193      4.680218
# min        0.000000          0.0           0.000000      0.000000
# 25%        0.000000          0.0           0.000000      0.000000
# 50%        2.000000          0.0           2.000000      0.000000
# 75%        6.000000          0.0           6.000000      3.000000
# max       88.000000          0.0         163.000000     61.000000
#
#          holdPings  ...          g_11          g_12          g_13  \
# count  7788.000000  ...   7788.000000   7788.000000   7788.000000
# mean      0.023754  ...   4429.048023   4869.560734   5315.529661
# std       0.213397  ...   2706.591258   2877.335278   3165.116727
# min       0.000000  ...   1623.000000   1745.000000   1867.000000
# 25%       0.000000  ...   3086.000000   3407.000000   3719.750000
# 50%       0.000000  ...   3607.000000   3988.000000   4354.000000
# 75%       0.000000  ...   4267.000000   4743.250000   5212.000000
# max       7.000000  ...  16930.000000  20695.000000  21395.000000
# 4    KR_6863636982          1607  13.24.547.9214            츄빠삐무야호
# ..             ...           ...             ...               ...
# 327  KR_6880547509          1899  13.24.547.9214           아삭한 아이디
# 328  KR_6880547509          1899  13.24.547.9214  blanc doux oligo
# 329  KR_6880547509          1899  13.24.547.9214           Pingeon
# 330  KR_6880547509          1899  13.24.547.9214     Nostradamus그랩
# 331  KR_6880547509          1899  13.24.547.9214           스마트생명과학
#
#      summonerLevel  participantId championName  champExperience teamPosition  \
# 0               68              1         Sett             9716          TOP
# 1              214              2        Viego            12301       JUNGLE
# 2              216              3        Sylas            11876       MIDDLE
# 3              407              4       Ezreal            11857       BOTTOM
# 4               61              5          Lux             9334      UTILITY
# ..             ...            ...          ...              ...          ...
# 327            248              6          Jax            16523          TOP
# 328             47              7     JarvanIV            11631       JUNGLE
# 329            205              8        Yasuo            11915       MIDDLE
# 330            262              9         Ashe            15345       BOTTOM
# 331            103             10         Pyke             9291      UTILITY
#
#      teamId  ...  g_16  g_17  g_18  g_19   g_20   g_21   g_22   g_23   g_24  \
# 0       100  ...  5205  6118  6410  6533   6840   6963   7110   7232   7365
# 1       100  ...  6845  7336  7856  8147   8699   8821   9486   9862  10069
# 2       100  ...  6951  7322  7647  7863   8675   8798   8980   9117   9558
# 3       100  ...  6128  6651  7495  7617   8016   8888   9140   9653  10075
# 4       100  ...  5541  6255  6395  6599   6760   6901   7124   7264   7494
# ..      ...  ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 327     200  ...  6096  6303  7441  7696   8572   9240   9420   9862  10138
# 328     200  ...  5825  6062  6205  6647   7145   7392   7875   8072   8567
# 329     200  ...  4665  4949  5416  5559   5817   5974   6098   6263   6811
# 330     200  ...  6406  6953  8607  9550  10157  10856  10979  11381  11828
# 331     200  ...  4729  5333  5734  5875   6115   6331   6581   6797   7237
#
#       g_25
# 0     7638
# 1    10765
# 2    10476
# 3    10318
# 4     7798
# ..     ...
# 327  11303
# 328   8977
# 329   7052
# 330  12334
# 331   7518
#
# [332 rows x 37 columns]

# %%
df['matches'][0]['info']['participants'][0]['summonerName'] # summonerName
# Out:
# '갓청하 사랑해'

# %%
df['matches'][0]['info']['participants'][0]
# Out:
# {'allInPings': 0,
#  'assistMePings': 2,
#  'assists': 5,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 126,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 492.2124842579482,
#   'damageTakenOnTeamPercentage': 0.24028827662812277,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 10,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 58,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#   'epicMonsterSteals': 0,
#   'epicMonsterStolenWithoutSmite': 0,
#   'firstTurretKilled': 1,
#   'firstTurretKilledTime': 736.0026114,
#   'flawlessAces': 0,
#   'fullTeamTakedown': 0,
#   'gameLength': 1607.0723509,
#   'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#   'goldPerMinute': 302.67306228821576,
#   'hadOpenNexus': 0,
#   'immobilizeAndKillWithAlly': 4,
#   'initialBuffCount': 0,
#   'initialCrabCount': 0,
#   'jungleCsBefore10Minutes': 0,
#   'junglerTakedownsNearDamagedEpicMonster': 0,
#   'kTurretsDestroyedBeforePlatesFall': 0,
#   'kda': 0.5,
#   'killAfterHiddenWithAlly': 0,
#   'killParticipation': 0.19230769230769232,
#   'killedChampTookFullTeamDamageSurvived': 0,
#   'killingSprees': 0,
#   'killsNearEnemyTurret': 0,
#   'killsOnOtherLanesEarlyJungleAsLaner': 0,
#   'killsOnRecentlyHealedByAramPack': 0,
#   'killsUnderOwnTurret': 0,
#   'killsWithHelpFromEpicMonster': 1,
#   'knockEnemyIntoTeamAndKill': 4,
#   'landSkillShotsEarlyGame': 0,
#   'laneMinionsFirst10Minutes': 55,
#   'laningPhaseGoldExpAdvantage': 0,
#   'legendaryCount': 0,
#   'lostAnInhibitor': 0,
#   'maxCsAdvantageOnLaneOpponent': 3,
#   'maxKillDeficit': 0,
#   'maxLevelLeadLaneOpponent': 1,
#   'mejaisFullStackInTime': 0,
#   'moreEnemyJungleThanOpponent': 0,
#   'multiKillOneSpell': 0,
#   'multiTurretRiftHeraldCount': 0,
#   'multikills': 0,
#   'multikillsAfterAggressiveFlash': 0,
#   'mythicItemUsed': 6631,
#   'outerTurretExecutesBefore10Minutes': 0,
#   'outnumberedKills': 0,
#   'outnumberedNexusKill': 0,
#   'perfectDragonSoulsTaken': 0,
#   'perfectGame': 0,
#   'pickKillWithAlly': 5,
#   'playedChampSelectPosition': 1,
#   'poroExplosions': 0,
#   'quickCleanse': 0,
#   'quickFirstTurret': 0,
#   'quickSoloKills': 0,
#   'riftHeraldTakedowns': 0,
#   'saveAllyFromDeath': 0,
#   'scuttleCrabKills': 0,
#   'skillshotsDodged': 2,
#   'skillshotsHit': 0,
#   'snowballsHit': 0,
#   'soloBaronKills': 0,
#   'soloKills': 0,
#   'soloTurretsLategame': 2,
#   'stealthWardsPlaced': 6,
#   'survivedSingleDigitHpCount': 0,
#   'survivedThreeImmobilizesInFight': 2,
#   'takedownOnFirstTurret': 0,
#   'takedowns': 5,
#   'takedownsAfterGainingLevelAdvantage': 0,
#   'takedownsBeforeJungleMinionSpawn': 0,
#   'takedownsFirstXMinutes': 2,
#   'takedownsInAlcove': 0,
#   'takedownsInEnemyFountain': 0,
#   'teamBaronKills': 0,
#   'teamDamagePercentage': 0.15056146660758155,
#   'teamElderDragonKills': 0,
#   'teamRiftHeraldKills': 2,
#   'tookLargeDamageSurvived': 0,
#   'turretPlatesTaken': 2,
#   'turretTakedowns': 2,
#   'turretsTakenWithRiftHerald': 10,
#   'twentyMinionsIn3SecondsCount': 0,
#   'twoWardsOneSweeperCount': 0,
#   'unseenRecalls': 0,
#   'visionScoreAdvantageLaneOpponent': -0.14037972688674927,
#   'visionScorePerMinute': 0.38998975514295975,
#   'wardTakedowns': 1,
#   'wardTakedownsBefore20M': 0,
#   'wardsGuarded': 0},
#  'champExperience': 9716,
#  'champLevel': 12,
#  'championId': 875,
#  'championName': 'Sett',
#  'championTransform': 0,
#  'commandPings': 9,
#  'consumablesPurchased': 1,
#  'damageDealtToBuildings': 6594,
#  'damageDealtToObjectives': 6594,
#  'damageDealtToTurrets': 6594,
#  'damageSelfMitigated': 23252,
#  'dangerPings': 0,
#  'deaths': 10,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 0,
#  'dragonKills': 0,
#  'eligibleForProgression': True,
#  'enemyMissingPings': 3,
#  'enemyVisionPings': 1,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'getBackPings': 3,
#  'goldEarned': 8106,
#  'goldSpent': 7820,
#  'holdPings': 0,
#  'individualPosition': 'TOP',
#  'inhibitorKills': 0,
#  'inhibitorTakedowns': 0,
#  'inhibitorsLost': 2,
#  'item0': 6631,
#  'item1': 3047,
#  'item2': 3133,
#  'item3': 1054,
#  'item4': 3067,
#  'item5': 0,
#  'item6': 3340,
#  'itemsPurchased': 14,
#  'killingSprees': 0,
#  'kills': 0,
#  'lane': 'TOP',
#  'largestCriticalStrike': 0,
#  'largestKillingSpree': 0,
#  'largestMultiKill': 0,
#  'longestTimeSpentLiving': 290,
#  'magicDamageDealt': 0,
#  'magicDamageDealtToChampions': 0,
#  'magicDamageTaken': 7769,
#  'missions': {'playerScore0': 0,
#   'playerScore1': 0,
#   'playerScore10': 0,
#   'playerScore11': 0,
#   'playerScore2': 0,
#   'playerScore3': 0,
#   'playerScore4': 0,
#   'playerScore5': 0,
#   'playerScore6': 0,
#   'playerScore7': 0,
#   'playerScore8': 0,
#   'playerScore9': 0},
#  'needVisionPings': 0,
#  'neutralMinionsKilled': 0,
#  'nexusKills': 0,
#  'nexusLost': 1,
#  'nexusTakedowns': 0,
#  'objectivesStolen': 0,
#  'objectivesStolenAssists': 0,
#  'onMyWayPings': 0,
#  'participantId': 1,
#  'pentaKills': 0,
#  'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#   'styles': [{'description': 'primaryStyle',
#     'selections': [{'perk': 8010, 'var1': 131, 'var2': 0, 'var3': 0},
#      {'perk': 9111, 'var1': 341, 'var2': 100, 'var3': 0},
#      {'perk': 9104, 'var1': 0, 'var2': 0, 'var3': 0},
#      {'perk': 8299, 'var1': 388, 'var2': 0, 'var3': 0}],
#     'style': 8000},
#    {'description': 'subStyle',
#     'selections': [{'perk': 8242, 'var1': 96, 'var2': 0, 'var3': 0},
#      {'perk': 8444, 'var1': 965, 'var2': 0, 'var3': 0}],
#     'style': 8400}]},
#  'physicalDamageDealt': 73331,
#  'physicalDamageDealtToChampions': 11354,
#  'physicalDamageTaken': 19677,
#  'placement': 0,
#  'playerAugment1': 0,
#  'playerAugment2': 0,
#  'playerAugment3': 0,
#  'playerAugment4': 0,
#  'playerScore0': 0,
#  'playerScore1': 0,
#  'playerScore10': 0,
#  'playerScore11': 0,
#  'playerScore2': 0,
#  'playerScore3': 0,
#  'playerScore4': 0,
#  'playerScore5': 0,
#  'playerScore6': 0,
#  'playerScore7': 0,
#  'playerScore8': 0,
#  'playerScore9': 0,
#  'playerSubteamId': 0,
#  'profileIcon': 5528,
#  'pushPings': 0,
#  'puuid': '4o7X9dQ13iCjMoaUoFgISUL7xCA_5tjLseFAnEvNdZbjbtIFVnLAZPmzYa_U6DOQ8n_apXW_5jRXgQ',
#  'quadraKills': 0,
#  'riotIdGameName': '샤프 심 없음',
#  'riotIdTagline': 'KR1',
#  'role': 'SOLO',
#  'sightWardsBoughtInGame': 0,
#  'spell1Casts': 64,
#  'spell2Casts': 23,
#  'spell3Casts': 34,
#  'spell4Casts': 5,
#  'subteamPlacement': 0,
#  'summoner1Casts': 4,
#  'summoner1Id': 12,
#  'summoner2Casts': 4,
#  'summoner2Id': 4,
#  'summonerId': 'rdKkovX5244kId0OGC9CHXSkjJ9KIOmHX2Ee89V7zMPEaJvE',
#  'summonerLevel': 68,
#  'summonerName': '샤프 심 없음',
#  'teamEarlySurrendered': False,
#  'teamId': 100,
#  'teamPosition': 'TOP',
#  'timeCCingOthers': 21,
#  'timePlayed': 1607,
#  'totalAllyJungleMinionsKilled': 0,
#  'totalDamageDealt': 88540,
#  'totalDamageDealtToChampions': 13183,
#  'totalDamageShieldedOnTeammates': 0,
#  'totalDamageTaken': 29284,
#  'totalEnemyJungleMinionsKilled': 0,
#  'totalHeal': 1646,
#  'totalHealsOnTeammates': 0,
#  'totalMinionsKilled': 117,
#  'totalTimeCCDealt': 185,
#  'totalTimeSpentDead': 280,
#  'totalUnitsHealed': 1,
#  'tripleKills': 0,
#  'trueDamageDealt': 15208,
#  'trueDamageDealtToChampions': 1829,
#  'trueDamageTaken': 1837,
#  'turretKills': 2,
#  'turretTakedowns': 2,
#  'turretsLost': 10,
#  'unrealKills': 0,
#  'visionClearedPings': 0,
#  'visionScore': 10,
#  'visionWardsBoughtInGame': 0,
#  'wardsKilled': 1,
#  'wardsPlaced': 6,
#  'win': False}

# %%
df['matches'][0]['info']['participants'][0]['allInPings'] # allInPings
# Out:
# 0

# %%
df['matches'][0]['info']['participants'][0]['assistMePings'] # assistMePings
# Out:
# 2

# %%
df['matches'][0]['info']['participants'][0]['baitPings'] # baitPings
# Out:
# 0

# %%
df['matches'][0]['info']['participants'][0]['basicPings'] # basicPings
# Out:
# 0

# %%
df.iloc[0].matches['info']['participants'][0]['commandPings'] #commandPings
# Out:
# 9

# %%
df.iloc[0].matches['info']['participants'][0]['dangerPings'] #dangerPings
# Out:
# 0

# %%
df.iloc[0].matches['info']['participants'][0]['enemyMissingPings'] #enemyMissingPings
# Out:
# 3

# %%
df.iloc[0].matches['info']['participants'][0]['enemyVisionPings'] #enemyVisionPings
# Out:
# 1

# %%
df.iloc[0].matches['info']['participants'][0]['getBackPings'] # getBackPings
# Out:
# 3

# %%
df.iloc[0].matches['info']['participants'][0]['holdPings'] # holdPings
# Out:
# 0

# %%
df.iloc[0].matches['info']['participants'][0]['needVisionPings'] #needVisionPings
# Out:
# 0

# %%
df.iloc[0].matches['info']['participants'][0]['onMyWayPings'] #onMyWayPings
# Out:
# 0

# %%
df.iloc[0].matches['info']['participants'][0]['pushPings'] #pushPings
# Out:
# 0

# %%
df.iloc[0].matches['info']['participants'][0]['visionClearedPings'] #visionClearedPings
# Out:
# 0

# %%
df3 = get_match_timeline_df(df)
# Out:
# 소환사 스텟 생성중.....
#   8%|██████▉                                                                            | 3/36 [00:00<00:01, 27.73it/s]
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
#  53%|███████████████████████████████████████████▎                                      | 19/36 [00:00<00:00, 28.74it/s]
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
#  81%|██████████████████████████████████████████████████████████████████                | 29/36 [00:01<00:00, 27.51it/s]
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# 24
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# 30
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [00:01<00:00, 29.89it/s]
# df 제작이 완료되었습니다. 현재 df의 수는 346 입니다

# %%
df3
# Out:
#             gameId  gameDuration  summonerName  summonerLevel  participantId  \
# 0    KR_6694267493          2542  163Cm45Kg70C            507              1
# 1    KR_6694267493          2542           시니루            321              2
# 2    KR_6694267493          2542          축구박사            297              3
# 3    KR_6694267493          2542      케이맞은케이틀린             41              4
# 4    KR_6694267493          2542      다이기진못하겠다            117              5
# ..             ...           ...           ...            ...            ...
# 341  KR_6871031309          2073           검바씌            113              6
# 342  KR_6871031309          2073    강고양OIOI상하다            274              7
# 343  KR_6871031309          2073           마달E            142              8
# 344  KR_6871031309          2073           수딕님            400              9
# 345  KR_6871031309          2073           홍형님            220             10
#
#     championName  champExperience  allInPings  assistMePings  baitPings  ...  \
# 0           Yone            19369           1              9          0  ...
# 1           Kayn            22205           1              8          0  ...
# 2          Ziggs            16882           0              6          0  ...
# 3           Ashe            15925           0              0          0  ...
# 4         Xerath            16821           1              1          0  ...
# ..           ...              ...         ...            ...        ...  ...
# 341       Kennen            16452           0             15          0  ...
# 342        Viego            16304           1              9          0  ...
# 343        Kayle            18111           0              2          0  ...
# 344        Yasuo            17365           0              0          0  ...
# 345     Malphite            11400           0              0          0  ...
#
#      g_11  g_12  g_13  g_14  g_15  g_16  g_17  g_18  g_19  g_20
# 0    2948  3225  3473  3765  4033  4738  4895  5187  5310  5674
# 1    4495  5237  5675  6012  6388  7071  7292  7926  8048  8697
# 2    2861  3060  3315  3530  3807  4326  4532  4772  5000  5192
# 3    3442  3835  4041  4440  5290  5412  5534  5657  5842  6186
# 4    2661  2961  3151  3579  4144  4778  4953  5177  5512  5793
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
#
# ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 7783  ...  3987  4323  4754  5056  5409  5767  6365  6885  7050  7489
# 7784  ...  3923  4364  4862  5199  5669  5991  6318  7042  7248  7598
# 7785  ...  3773  4049  4260  4569  5095  5439  5561  5984  6285  6672
# 7786  ...  4194  4701  4957  5412  5807  6220  6758  7512  8199  8754
# 7787  ...  2652  2872  3088  3445  3600  3919  4445  4810  5116  5284
#
# [7788 rows x 47 columns]

# %%
import pandas as pd

# 예시 데이터프레임 생성
data = {'Column1': [1, 2, 3],
        'Column2': [4, 5, 6],
        'Column3': [7, 8, 9]}
df = pd.DataFrame(data)

# 선택한 열들의 값을 합하여 새로운 열 생성
selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
result_df_IRON['Sum_Selected'] = result_df_IRON[selected_columns].sum(axis=1)

# 결과 출력
result_df_IRON
# Out:
#              gameId  gameDuration  allInPings  assistMePings  basicPings  \
# 0     KR_6841974869          1861           0              0           0
# 1     KR_6841974869          1861           0              1           0
# 2     KR_6841974869          1861           1              2           0
# 3     KR_6841974869          1861           0              2           0
# 4     KR_6841974869          1861           0              2           0
# ...             ...           ...         ...            ...         ...
# 7783  KR_6866314283          1744           0              1           0
# 7784  KR_6866314283          1744           0              0           0
# 7785  KR_6866314283          1744           0             11           0
# 7786  KR_6866314283          1744           0              0           0
# 7787  KR_6866314283          1744           1              3           0
#
#       commandPings  dangerPings  enemyMissingPings  getBackPings  \
# 0                5            0                  9             2
# 1                3            0                 11             3
# 2                3            0                 17            10
# 3                2            0                  8             4
# 4               11            0                  0             6
# ...            ...          ...                ...           ...
# 7783            13            0                  4             0
# 7784             1            0                  6             4
# 7785             0            0                  1             1
# 7786             4            0                  0             3
# 7787             4            0                  0             1
#
#       needVisionPings  ...  g_12  g_13  g_14  g_15  g_16  g_17  g_18  g_19  \
# 0                   0  ...  4683  5284  5637  5991  6218  7330  7740  7925
# 1                   0  ...  3618  3745  4083  4290  4721  4913  5306  5973
# 2                   0  ...  3562  3727  3979  4333  4961  5133  5404  5617
# 3                   0  ...  4350  4724  5047  5295  5492  5665  6213  6434
# 4                   0  ...  3538  3863  4080  4384  4688  4888  5295  5714
# ...               ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 7783                0  ...  4323  4754  5056  5409  5767  6365  6885  7050
# 7784                0  ...  4364  4862  5199  5669  5991  6318  7042  7248
# 7785                0  ...  4049  4260  4569  5095  5439  5561  5984  6285
# 7786                0  ...  4701  4957  5412  5807  6220  6758  7512  8199
# 7787                0  ...  2872  3088  3445  3600  3919  4445  4810  5116
#
#       g_20 Sum_Selected
# 0     8593           21
# 1     6229           46
# 2     6839           33
# 3     6917           20
# 4     6066           22
# ...    ...          ...
# 7783  7489           20
# 7784  7598           16
# 7785  6672           13
# 7786  8754           15
# 7787  5284           13
#
# [6977 rows x 45 columns]

# %%
result_df_IRON = result_df_IRON[result_df_IRON.teamPosition != ""]

result_df_IRON = result_df_IRON.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

# %%
result_df_DIAMOND = result_df_DIAMOND.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

# %%
result_df_DIAMOND
# Out:
#              gameId  gameDuration  allInPings  assistMePings  basicPings  \
# 
ameId  gameDuration  allInPings  assistMePings  basicPings  \
# 0     KR_6692328762          1326           0              2           0
# 1     KR_6692328762          1326           0              2           0
# 2     KR_6692328762          1326           0              1           0
# 3     KR_6692328762          1326           0              0           0
# 4     KR_6692328762          1326           0              0           0
# ...             ...           ...         ...            ...         ...
# 8257  KR_6754980551          2078           0              5           0
# 8258  KR_6754980551          2078           0              2           0
# 8259  KR_6754980551          2078           0              0           0
# 8260  KR_6754980551          2078           0              1           0
# 8261  KR_6754980551          2078           0              1           0
#
#       commandPings  dangerPings  enemyMissingPings  getBackPings  \
# 0                2            0                  2             0
# 1                1            0                  4             0
# 2                5            0                  1             0
# 3                0            0                  8             0
# 4                6            0                  6             0
# ...            ...          ...                ...           ...
# 8257            29            0                 10             0
# 8258             0            0                  1             1
# 8259             0            0                  0             0
# 8260             4            0                  0             2
# 8261            40            0                  6             0
#
#       needVisionPings  ...  g_13  g_14  g_15  g_16  g_17  g_18  g_19  g_20  \
# 0                   0  ...  3946  4167  4303  4757  5165  5287  5431  5721
# 1                   0  ...  4756  4879  5111  5962  6213  6336  6562  7084
# 2                   0  ...  3782  3910  4415  4680  5086  5208  5652  5941
# 3                   0  ...  5295  5809  6044  6912  7056  7269  7391  7598
# 4                   0  ...  3973  4487  4763  5347  5501  5647  5857  5998
# ...               ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 8257                0  ...  3176  3690  4132  4425  4598  5145  5477  5632
# 8258                0  ...  4785  5120  5687  5855  6506  6809  7342  7949
# 8259                0  ...  6077  6663  7129  7454  7892  8443  8875  9712
# 8260                0  ...  6791  7274  7829  8234  8696  8901  9107  9610
# 8261                0  ...  5507  5799  5979  6274  6635  7333  7537  7990
#
#       Sum_Selected    tier
# 0                7  BRONZE
# 1                7  BRONZE
# 2                8  BRONZE
# 3                8  BRONZE
# 4               12  BRONZE
# ...            ...     ...
# 8257            55  BRONZE
# 8258             4  BRONZE
# 8259             1  BRONZE
# 8260            37  BRONZE
# 8261            64  BRONZE
#
# [7389 rows x 46 columns]

# %%
import pandas as pd

# 예시 데이터프레임 생성
data = {'win': [True, False, True],
        'numbers': [10, 20, 30]}
df = pd.DataFrame(data)

# 'win'이 True인 행의 'numbers' 값 합계
sum_true = result_df_DIAMOND.loc[result_df_DIAMOND['win'] == 'True', 'Sum_Selected'].sum()

# 'win'이 False인 행의 'numbers' 값 합계
sum_false = result_df_DIAMOND.loc[result_df_DIAMOND['win'] == 'False', 'Sum_Selected'].sum()

# 결과 출력
print("Sum for True: ", sum_true)
print("Sum for False: ", sum_false)

# 합계를 비교
if sum_true > sum_false:
    print("True has a higher sum.")
elif sum_true < sum_false:
    print("False has a higher sum.")
else:
    print("Sums are equal.")
# Out:
# Sum for True:  116391
# Sum for False:  101777
# True has a higher sum.

# %%
sum_true
# Out:
# 76723

# %%
selected_rows = result_df[(result_df['g_2'] >= 900) & (result_df['win'] == 'True')]

# 전체 판수
total_games = len(result_df[result_df['g_2'] >= 900])

print(total_games)

# 조건에 해당하는 판수
selected_games = len(selected_rows)

print(selected_games)

# 승률 계산
win_rate = selected_games / total_games * 100
# Out:
# 225
# 121

# %%
iron_issue_win = round(win_rate, 1)
# bro_issue_win = round(win_rate, 1)
# sil_issue_win = round(win_rate, 1)
# gold_issue_win = round(win_rate, 1)
# pla_issue_win = round(win_rate, 1)
# eme_issue_win = round(win_rate, 1)
# dia_issue_win = round(win_rate, 1)

# %%
selected_rows2 = result_df[(result['g_2'] < 900) & (result['win'] == 'True')]

# 전체 판수
total_games2 = len(result[result['g_2'] < 900])

print(total_games2)

# 조건에 해당하는 판수
selected_games2 = len(selected_rows2)

print(selected_games2)

# 승률 계산
win_rate2 = selected_games2 / total_games2 * 100

# %%
# iron_no_issue_win = round(win_rate2, 1)
# bro_no_issue_win = round(win_rate2, 1)
# sil_no_issue_win = round(win_rate2, 1)
# gold_no_issue_win = round(win_rate2, 1)
# pla_no_issue_win = round(win_rate2, 1)
# eme_no_issue_win = round(win_rate2, 1)
dia_no_issue_win = round(win_rate2, 1)

# %%
tiers = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND']

result_df = pd.DataFrame(index=tiers, columns=['이긴 팀의 총 핑 횟수', '진 팀의 총 핑 횟수'])

# %%
result_df.loc['DIAMOND', '이긴 팀의 총 핑 횟수'] = sum_true
result_df.loc['DIAMOND', '진 팀의 총 핑 횟수'] = sum_false

# %%
result_df_SILVER
# Out:
#              gameId  gameDuration  allInPings  assistMePings  basicPings  \
# 0     KR_6824522820          1839           0              3           0
# 1     KR_6824522820          1839           0              3           0
# 2     KR_6824522820          1839           0             13           0
# 3     KR_6824522820          1839           0              4           0
# 4     KR_6824522820          1839           0              0           0
# ...             ...           ...         ...            ...         ...
# 8091  KR_6686770771          1588           0              0           0
# 8092  KR_6686770771          1588           0              0           0
# 8093  KR_6686770771          1588           2              1           0
# 8094  KR_6686770771          1588           0              0           0
# 8095  KR_6686770771          1588           0              0           0
#
#       commandPings  dangerPings  enemyMissingPings  getBackPings  \
# 0               10            0                  9             0
# 1                7            0                  4             3
# 2                5            0                 16             7
# 3               16            0                  9            15
# 4                0            0                  1             6
# ...            ...          ...                ...           ...
# 8091             0            0                  9             0
# 8092             6            0                 14             5
# 8093            12            0                  8             0
# 8094             1            0                 14             4
# 8095             1            0                  0             0
#
#       needVisionPings  ...  g_13  g_14  g_15  g_16  g_17   g_18   g_19   g_20  \
# 0                   0  ...  4898  5209  5352  5580  5981   6109   6510   6956
# 1                   0  ...  4985  5188  5624  6095  6438   6960   7215   7922
# 2                   0  ...  4180  4524  5070  5378  5744   5887   6147   6379
# 3                   0  ...  5473  5781  6972  7286  8353   8734   8940   9341
# 4                   0  ...  3559  4000  4190  4330  4537   4712   4972   5177
# ...               ...  ...   ...   ...   ...   ...   ...    ...    ...    ...
# 8091                0  ...  4985  5291  5539  5928  6099   6529   7001   7430
# 8092                0  ...  4537  4960  5378  5619  5742   5914   6291   6414
# 8093                0  ...  7640  8613  9224  9451  9744  10112  10808  11572
# 8094                0  ...  3430  4222  4529  4894  5362   5620   5881   6154
# 8095                0  ...  3340  3598  3816  3956  4223   4504   4835   5032
#
#       Sum_Selected    tier
# 0               24  SILVER
# 1               32  SILVER
# 2               45  SILVER
# 3               49  SILVER
# 4               11  SILVER
# ...            ...     ...
# 8091            14  SILVER
# 8092            29  SILVER
# 8093            45  SILVER
# 8094            19  SILVER
# 8095             1  SILVER
#
# [7360 rows x 46 columns]

# %%
result_final = pd.merge(result_final,result_df_DIAMOND, how = 'outer')

# %%
result_final
# Out:
#               gameId  gameDuration  allInPings  assistMePings  basicPings  \
# 0      KR_6841974869          1861           0              0           0
# 1      KR_6841974869          1861           0              1           0
# 2      KR_6841974869          1861           1              2           0
# 3      KR_6841974869          1861           0              2           0
# 4      KR_6841974869          1861           0              2           0
# ...              ...           ...         ...            ...         ...
# 51641  KR_6883114038          1654           0              2           0
# 51642  KR_6883114038          1654           1             15           0
# 51643  KR_6883114038          1654           0              0           0
# 51644  KR_6883114038          1654           0              7           0
# 51645  KR_6883114038          1654           0              2           0
#
#        commandPings  dangerPings  enemyMissingPings  getBackPings  \
# 0                 5            0                  9             2
# 1                 3            0                 11             3
# 2                 3            0                 17            10
# 3                 2            0                  8             4
# 4                11            0                  0             6
# ...             ...          ...                ...           ...
# 51641             8            0                  8             8
# 51642            19            0                  5            18
# 51643            10            0                  0             0
# 51644             5            0                  1             0
# 51645             6            0                  3             5
#
#        needVisionPings  ...  g_13  g_14  g_15  g_16  g_17   g_18   g_19  \
# 0                    0  ...  5284  5637  5991  6218  7330   7740   7925
# 1                    0  ...  3745  4083  4290  4721  4913   5306   5973
# 2                    0  ...  3727  3979  4333  4961  5133   5404   5617
# 3                    0  ...  4724  5047  5295  5492  5665   6213   6434
# 4                    0  ...  3863  4080  4384  4688  4888   5295   5714
# ...                ...  ...   ...   ...   ...   ...   ...    ...    ...
# 51641                0  ...  3701  4521  4919  5052  5204   5720   6119
# 51642                0  ...  3684  4007  4299  4600  4781   5132   5464
# 51643                0  ...  4111  4608  5015  5158  5543   5799   6241
# 51644                0  ...  6931  7906  8581  8939  9492  10207  10677
# 51645                0  ...  4418  4830  5035  5297  5647   6071   6246
#
#         g_20  Sum_Selected     tier
# 0       8593            21     IRON
# 1       6229            46     IRON
# 2       6839            33     IRON
# 3       6917            20     IRON
# 4       6066            22     IRON
# ...      ...           ...      ...
# 51641   6564            33  DIAMOND
# 51642   5966            85  DIAMOND
# 51643   6680            10  DIAMOND
# 51644  11558            22  DIAMOND
# 51645   6703            18  DIAMOND
#
# [51646 rows x 46 columns]

# %%
result_df
# Out:
#          이긴 팀의 총 핑 횟수 진 팀의 총 핑 횟수
# IRON            76723       71748
# BRONZE          86587       79414
# SILVER          92112       82894
# GOLD            95747       85716
# PLATINUM        95002       82432
# EMERALD        112815       97429
# DIAMOND        116391      101777

# %%
df = pd.read_csv('result_df_issue.csv')
df
# Out:
#    이슈있는 승률  이슈없는 승률
# 0     53.8     49.9
# 1     58.3     49.7
# 2     57.2     49.8
# 3     55.5     49.8
# 4     53.3     49.9
# 5     59.9     49.6
# 6     59.2     49.6
